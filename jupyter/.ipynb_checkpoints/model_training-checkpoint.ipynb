# %%
import pandas as pd

df = pd.read_csv('../data/consolidated_results.csv')
features = ['total_filters', 'kernel_size', 'input_size', 'tpu_mode', 'usb_type', 'block_type', 'filters_per_layer', 'number_of_layers', 'total_power_avg']
X_power = df[features]
X_power
# Out:
#       total_filters  kernel_size  input_size tpu_mode usb_type block_type  \
# 0             26624            1        9216      std     usb2   fullconv
# 1             40960            1        9216      std     usb2   fullconv
# 2             31744            1        9216      std     usb2   fullconv
# 3             44288            1        9216      std     usb2   fullconv
# 4             61568            1        9216      std     usb2   fullconv
# ...             ...          ...         ...      ...      ...        ...
# 2613             50            3      192000      max     usb3  separable
# 2614             50            3      256000      max     usb3  separable
# 2615             50            3      384000      max     usb3  separable
# 2616             50            3      512000      max     usb3  separable
# 2617             50            3      640000      max     usb3  separable
#
#       filters_per_layer  number_of_layers  total_power_avg
# 0                  1024                26         4.295750
# 1                  1024                40         4.230833
# 2                   128               248         6.067273
# 3                   128               346         6.260636
# 4                   128               481         6.198545
# ...                 ...               ...              ...
# 2613                 10                 5         6.237500
# 2614                 10                 5         5.879167
# 2615                 10                 5         6.258439
# 2616                 10                 5         6.367769
# 2617                 10                 5         6.361647
#
# [2618 rows x 9 columns]

# %%
from pycaret.regression import *
power_models = setup(data = X_power, target = 'total_power_avg', session_id = "42")
# Out:
# <style type="text/css">
# #T_cef0b_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_cef0b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cef0b_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_cef0b_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cef0b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cef0b_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_cef0b_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_cef0b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cef0b_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_cef0b_row1_col1" class="data row1 col1" >total_power_avg</td>
#     </tr>
#     <tr>
#       <th id="T_cef0b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cef0b_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_cef0b_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_cef0b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cef0b_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_cef0b_row3_col1" class="data row3 col1" >(2618, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_cef0b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_cef0b_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_cef0b_row4_col1" class="data row4 col1" >(2618, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_cef0b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_cef0b_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_cef0b_row5_col1" class="data row5 col1" >(1832, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_cef0b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_cef0b_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_cef0b_row6_col1" class="data row6 col1" >(786, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_cef0b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_cef0b_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_cef0b_row7_col1" class="data row7 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_cef0b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_cef0b_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_cef0b_row8_col1" class="data row8 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_cef0b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_cef0b_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_cef0b_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_cef0b_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_cef0b_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_cef0b_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_cef0b_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_cef0b_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_cef0b_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_cef0b_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_cef0b_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_cef0b_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_cef0b_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_cef0b_row13_col0" class="data row13 col0" >Maximum one-hot encoding</td>
#       <td id="T_cef0b_row13_col1" class="data row13 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_cef0b_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_cef0b_row14_col0" class="data row14 col0" >Encoding method</td>
#       <td id="T_cef0b_row14_col1" class="data row14 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_cef0b_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_cef0b_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_cef0b_row15_col1" class="data row15 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_cef0b_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_cef0b_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_cef0b_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_cef0b_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_cef0b_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_cef0b_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_cef0b_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_cef0b_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_cef0b_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_cef0b_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_cef0b_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_cef0b_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_cef0b_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_cef0b_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_cef0b_row20_col1" class="data row20 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_cef0b_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_cef0b_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_cef0b_row21_col1" class="data row21 col1" >3475</td>
#     </tr>
#   </tbody>
# </table>

# %%
best_power_models = power_models.compare_models(sort="MAE")
# Out:
# <style type="text/css">
# #T_d905b th {
#   text-align: left;
# }
# #T_d905b_row0_col0, #T_d905b_row0_col2, #T_d905b_row0_col3, #T_d905b_row0_col4, #T_d905b_row0_col5, #T_d905b_row1_col0, #T_d905b_row1_col1, #T_d905b_row1_col6, #T_d905b_row2_col0, #T_d905b_row2_col1, #T_d905b_row2_col2, #T_d905b_row2_col3, #T_d905b_row2_col4, #T_d905b_row2_col5, #T_d905b_row2_col6, #T_d905b_row3_col0, #T_d905b_row3_col1, #T_d905b_row3_col2, #T_d905b_row3_col3, #T_d905b_row3_col4, #T_d905b_row3_col5, #T_d905b_row3_col6, #T_d905b_row4_col0, #T_d905b_row4_col1, #T_d905b_row4_col2, #T_d905b_row4_col3, #T_d905b_row4_col4, #T_d905b_row4_col5, #T_d905b_row4_col6, #T_d905b_row5_col0, #T_d905b_row5_col1, #T_d905b_row5_col2, #T_d905b_row5_col3, #T_d905b_row5_col4, #T_d905b_row5_col5, #T_d905b_row5_col6, #T_d905b_row6_col0, #T_d905b_row6_col1, #T_d905b_row6_col2, #T_d905b_row6_col3, #T_d905b_row6_col4, #T_d905b_row6_col5, #T_d905b_row6_col6, #T_d905b_row7_col0, #T_d905b_row7_col1, #T_d905b_row7_col2, #T_d905b_row7_col3, #T_d905b_row7_col4, #T_d905b_row7_col5, #T_d905b_row7_col6, #T_d905b_row8_col0, #T_d905b_row8_col1, #T_d905b_row8_col2, #T_d905b_row8_col3, #T_d905b_row8_col4, #T_d905b_row8_col5, #T_d905b_row8_col6, #T_d905b_row9_col0, #T_d905b_row9_col1, #T_d905b_row9_col2, #T_d905b_row9_col3, #T_d905b_row9_col4, #T_d905b_row9_col5, #T_d905b_row9_col6, #T_d905b_row10_col0, #T_d905b_row10_col1, #T_d905b_row10_col2, #T_d905b_row10_col3, #T_d905b_row10_col4, #T_d905b_row10_col5, #T_d905b_row10_col6, #T_d905b_row11_col0, #T_d905b_row11_col1, #T_d905b_row11_col2, #T_d905b_row11_col3, #T_d905b_row11_col4, #T_d905b_row11_col5, #T_d905b_row11_col6, #T_d905b_row12_col0, #T_d905b_row12_col1, #T_d905b_row12_col2, #T_d905b_row12_col3, #T_d905b_row12_col4, #T_d905b_row12_col5, #T_d905b_row12_col6, #T_d905b_row13_col0, #T_d905b_row13_col1, #T_d905b_row13_col2, #T_d905b_row13_col3, #T_d905b_row13_col4, #T_d905b_row13_col5, #T_d905b_row13_col6, #T_d905b_row14_col0, #T_d905b_row14_col1, #T_d905b_row14_col2, #T_d905b_row14_col3, #T_d905b_row14_col4, #T_d905b_row14_col5, #T_d905b_row14_col6, #T_d905b_row15_col0, #T_d905b_row15_col1, #T_d905b_row15_col2, #T_d905b_row15_col3, #T_d905b_row15_col4, #T_d905b_row15_col5, #T_d905b_row15_col6, #T_d905b_row16_col0, #T_d905b_row16_col1, #T_d905b_row16_col2, #T_d905b_row16_col3, #T_d905b_row16_col4, #T_d905b_row16_col5, #T_d905b_row16_col6, #T_d905b_row17_col0, #T_d905b_row17_col1, #T_d905b_row17_col2, #T_d905b_row17_col3, #T_d905b_row17_col4, #T_d905b_row17_col5, #T_d905b_row17_col6, #T_d905b_row18_col0, #T_d905b_row18_col1, #T_d905b_row18_col2, #T_d905b_row18_col3, #T_d905b_row18_col4, #T_d905b_row18_col5, #T_d905b_row18_col6 {
#   text-align: left;
# }
# #T_d905b_row0_col1, #T_d905b_row0_col6, #T_d905b_row1_col2, #T_d905b_row1_col3, #T_d905b_row1_col4, #T_d905b_row1_col5 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_d905b_row0_col7, #T_d905b_row1_col7, #T_d905b_row2_col7, #T_d905b_row3_col7, #T_d905b_row5_col7, #T_d905b_row6_col7, #T_d905b_row7_col7, #T_d905b_row8_col7, #T_d905b_row9_col7, #T_d905b_row10_col7, #T_d905b_row11_col7, #T_d905b_row12_col7, #T_d905b_row13_col7, #T_d905b_row14_col7, #T_d905b_row15_col7, #T_d905b_row16_col7, #T_d905b_row17_col7, #T_d905b_row18_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_d905b_row4_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_d905b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d905b_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_d905b_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_d905b_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_d905b_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_d905b_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_d905b_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_d905b_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_d905b_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d905b_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_d905b_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_d905b_row0_col1" class="data row0 col1" >0.0892</td>
#       <td id="T_d905b_row0_col2" class="data row0 col2" >0.0258</td>
#       <td id="T_d905b_row0_col3" class="data row0 col3" >0.1582</td>
#       <td id="T_d905b_row0_col4" class="data row0 col4" >0.9427</td>
#       <td id="T_d905b_row0_col5" class="data row0 col5" >0.0243</td>
#       <td id="T_d905b_row0_col6" class="data row0 col6" >0.0161</td>
#       <td id="T_d905b_row0_col7" class="data row0 col7" >0.2260</td>
#     </tr>
#     <tr>
#       <th id="T_d905b_level0_row1" class="row_heading level0 row1" >catboost</th>
#       <td id="T_d905b_row1_col0" class="data row1 col0" >CatBoost Regressor</td>
#       <td id="T_d905b_row1_col1" class="data row1 col1" >0.0934</td>
#       <td id="T_d905b_row1_col2" class="data row1 col2" >0.0240</td>
#       <td id="T_d905b_row1_col3" class="data row1 col3" >0.1532</td>
#       <td id="T_d905b_row1_col4" class="data row1 col4" >0.9476</td>
#       <td id="T_d905b_row1_col5" class="data row1 col5" >0.0236</td>
#       <td id="T_d905b_row1_col6" class="data row1 col6" >0.0170</td>
#       <td id="T_d905b_row1_col7" class="data row1 col7" >1.3150</td>
#     </tr>
#     <tr>
#       <th id="T_d905b_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_d905b_row2_col0" class="data row2 col0" >Random Forest Regressor</td>
#       <td id="T_d905b_row2_col1" class="data row2 col1" >0.0966</td>
#       <td id="T_d905b_row2_col2" class="data row2 col2" >0.0301</td>
#       <td id="T_d905b_row2_col3" class="data row2 col3" >0.1692</td>
#       <td id="T_d905b_row2_col4" class="data row2 col4" >0.9335</td>
#       <td id="T_d905b_row2_col5" class="data row2 col5" >0.0258</td>
#       <td id="T_d905b_row2_col6" class="data row2 col6" >0.0174</td>
#       <td id="T_d905b_row2_col7" class="data row2 col7" >0.2490</td>
#     </tr>
#     <tr>
#       <th id="T_d905b_level0_row3" class="row_heading level0 row3" >lightgbm</th>
#       <td id="T_d905b_row3_col0" class="data row3 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_d905b_row3_col1" class="data row3 col1" >0.1043</td>
#       <td id="T_d905b_row3_col2" class="data row3 col2" >0.0300</td>
#       <td id="T_d905b_row3_col3" class="data row3 col3" >0.1720</td>
#       <td id="T_d905b_row3_col4" class="data row3 col4" >0.9348</td>
#       <td id="T_d905b_row3_col5" class="data row3 col5" >0.0263</td>
#       <td id="T_d905b_row3_col6" class="data row3 col6" >0.0189</td>
#       <td id="T_d905b_row3_col7" class="data row3 col7" >0.2470</td>
#     </tr>
#     <tr>
#       <th id="T_d905b_level0_row4" class="row_heading level0 row4" >dt</th>
#       <td id="T_d905b_row4_col0" class="data row4 col0" >Decision Tree Regressor</td>
#       <td id="T_d905b_row4_col1" class="data row4 col1" >0.1138</td>
#       <td id="T_d905b_row4_col2" class="data row4 col2" >0.0476</td>
#       <td id="T_d905b_row4_col3" class="data row4 col3" >0.2106</td>
#       <td id="T_d905b_row4_col4" class="data row4 col4" >0.8923</td>
#       <td id="T_d905b_row4_col5" class="data row4 col5" >0.0322</td>
#       <td id="T_d905b_row4_col6" class="data row4 col6" >0.0206</td>
#       <td id="T_d905b_row4_col7" class="data row4 col7" >0.0510</td>
#     </tr>
#     <tr>
#       <th id="T_d905b_level0_row5" class="row_heading level0 row5" >gbr</th>
#       <td id="T_d905b_row5_col0" class="data row5 col0" >Gradient Boosting Regressor</td>
#       <td id="T_d905b_row5_col1" class="data row5 col1" >0.1342</td>
#       <td id="T_d905b_row5_col2" class="data row5 col2" >0.0482</td>
#       <td id="T_d905b_row5_col3" class="data row5 col3" >0.2188</td>
#       <td id="T_d905b_row5_col4" class="data row5 col4" >0.8969</td>
#       <td id="T_d905b_row5_col5" class="data row5 col5" >0.0331</td>
#       <td id="

# %%
plot_model(best_power_models, plot = 'error')

# %%
plot_model(best_power_models, plot = 'feature')

# %%
tuned_power_model = tune_model(best_power_models, n_iter = 50)
evaluate_model(tuned_power_model)
final_power_model = finalize_model(tuned_power_model)
save_model(final_power_model, '../models/power_model')
# Out:
# <style type="text/css">
# #T_c3e38_row10_col0, #T_c3e38_row10_col1, #T_c3e38_row10_col2, #T_c3e38_row10_col3, #T_c3e38_row10_col4, #T_c3e38_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_c3e38">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c3e38_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_c3e38_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_c3e38_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_c3e38_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_c3e38_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_c3e38_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c3e38_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c3e38_row0_col0" class="data row0 col0" >0.1643</td>
#       <td id="T_c3e38_row0_col1" class="data row0 col1" >0.0693</td>
#       <td id="T_c3e38_row0_col2" class="data row0 col2" >0.2633</td>
#       <td id="T_c3e38_row0_col3" class="data row0 col3" >0.8661</td>
#       <td id="T_c3e38_row0_col4" class="data row0 col4" >0.0390</td>
#       <td id="T_c3e38_row0_col5" class="data row0 col5" >0.0296</td>
#     </tr>
#     <tr>
#       <th id="T_c3e38_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c3e38_row1_col0" class="data row1 col0" >0.1576</td>
#       <td id="T_c3e38_row1_col1" class="data row1 col1" >0.0591</td>
#       <td id="T_c3e38_row1_col2" class="data row1 col2" >0.2432</td>
#       <td id="T_c3e38_row1_col3" class="data row1 col3" >0.8759</td>
#       <td id="T_c3e38_row1_col4" class="data row1 col4" >0.0367</td>
#       <td id="T_c3e38_row1_col5" class="data row1 col5" >0.0281</td>
#     </tr>
#     <tr>
#       <th id="T_c3e38_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c3e38_row2_col0" class="data row2 col0" >0.1538</td>
#       <td id="T_c3e38_row2_col1" class="data row2 col1" >0.0581</td>
#       <td id="T_c3e38_row2_col2" class="data row2 col2" >0.2411</td>
#       <td id="T_c3e38_row2_col3" class="data row2 col3" >0.8532</td>
#       <td id="T_c3e38_row2_col4" class="data row2 col4" >0.0350</td>
#       <td id="T_c3e38_row2_col5" class="data row2 col5" >0.0270</td>
#     </tr>
#     <tr>
#       <th id="T_c3e38_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c3e38_row3_col0" class="data row3 col0" >0.1391</td>
#       <td id="T_c3e38_row3_col1" class="data row3 col1" >0.0469</td>
#       <td id="T_c3e38_row3_col2" class="data row3 col2" >0.2166</td>
#       <td id="T_c3e38_row3_col3" class="data row3 col3" >0.8906</td>
#       <td id="T_c3e38_row3_col4" class="data row3 col4" >0.0331</td>
#       <td id="T_c3e38_row3_col5" class="data row3 col5" >0.0256</td>
#     </tr>
#     <tr>
#       <th id="T_c3e38_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c3e38_row4_col0" class="data row4 col0" >0.1316</td>
#       <td id="T_c3e38_row4_col1" class="data row4 col1" >0.0504</td>
#       <td id="T_c3e38_row4_col2" class="data row4 col2" >0.2244</td>
#       <td id="T_c3e38_row4_col3" class="data row4 col3" >0.8600</td>
#       <td id="T_c3e38_row4_col4" class="data row4 col4" >0.0342</td>
#       <td id="T_c3e38_row4_col5" class="data row4 col5" >0.0242</td>
#     </tr>
#     <tr>
#       <th id="T_c3e38_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c3e38_row5_col0" class="data row5 col0" >0.1579</td>
#       <td id="T_c3e38_row5_col1" class="data row5 col1" >0.0625</td>
#       <td id="T_c3e38_row5_col2" class="data row5 col2" >0.2500</td>
#       <td id="T_c3e38_row5_col3" class="data row5 col3" >0.8897</td>
#       <td id="T_c3e38_row5_col4" class="data row5 col4" >0.0375</td>
#       <td id="T_c3e38_row5_col5" class="data row5 col5" >0.0282</td>
#     </tr>
#     <tr>
#       <th id="T_c3e38_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c3e38_row6_col0" class="data row6 col0" >0.1355</td>
#       <td id="T_c3e38_row6_col1" class="data row6 col1" >0.0475</td>
#       <td id="T_c3e38_row6_col2" class="data row6 col2" >0.2180</td>
#       <td id="T_c3e38_row6_col3" class="data row6 col3" >0.9281</td>
#       <td id="T_c3e38_row6_col4" class="data row6 col4" >0.0329</td>
#       <td id="T_c3e38_row6_col5" class="data row6 col5" >0.0248</td>
#     </tr>
#     <tr>
#       <th id="T_c3e38_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c3e38_row7_col0" class="data row7 col0" >0.1545</td>
#       <td id="T_c3e38_row7_col1" class="data row7 col1" >0.0611</td>
#       <td id="T_c3e38_row7_col2" class="data row7 col2" >0.2472</td>
#       <td id="T_c3e38_row7_col3" class="data row7 col3" >0.8434</td>
#       <td id="T_c3e38_row7_col4" class="data row7 col4" >0.0372</td>
#       <td id="T_c3e38_row7_col5" class="data row7 col5" >0.0274</td>
#     </tr>
#     <tr>
#       <th id="T_c3e38_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c3e38_row8_col0" class="data row8 col0" >0.1597</td>
#       <td id="T_c3e38_row8_col1" class="data row8 col1" >0.0641</td>
#       <td id="T_c3e38_row8_col2" class="data row8 col2" >0.2532</td>
#       <td id="T_c3e38_row8_col3" class="data row8 col3" >0.8847</td>
#       <td id="T_c3e38_row8_col4" class="data row8 col4" >0.0373</td>
#       <td id="T_c3e38_row8_col5" class="data row8 col5" >0.0281</td>
#     </tr>
#     <tr>
#       <th id="T_c3e38_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c3e38_row9_col0" class="data row9 col0" >0.1113</td>
#       <td id="T_c3e38_row9_col1" class="data row9 col1" >0.0308</td>
#       <td id="T_c3e38_row9_col2" class="data row9 col2" >0.1755</td>
#       <td id="T_c3e38_row9_col3" class="data row9 col3" >0.9317</td>
#       <td id="T_c3e38_row9_col4" class="data row9 col4" >0.0263</td>
#       <td id="T_c3e38_row9_col5" class="data row9 col5" >0.0200</td>
#     </tr>
#     <tr>
#       <th id="T_c3e38_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_c3e38_row10_col0" class="data row10 col0" >0.1465</td>
#       <td id="T_c3e38_row10_col1" class="data row10 col1" >0.0550</td>
#       <td id="T_c3e38_row10_col2" class="data row10 col2" >0.2332</td>
#       <td id="T_c3e38_row10_col3" class="data row10 col3" >0.8823</td>
#       <td id="T_c3e38_row10_col4" class="data row10 col4" >0.0349</td>
#       <td id="T_c3e38_row10_col5" class="data row10 col5" >0.0263</td>
#     </tr>
#     <tr>
#       <th id="T_c3e38_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_c3e38_row11_col0" class="data row11 col0" >0.0158</td>
#       <td id="T_c3e38_row11_col1" class="data row11 col1" >0.0107</td>
#       <td id="T_c3e38_row11_col2" class="data row11 col2" >0.0242</td>
#       <td id="T_c3e38_row11_col3" class="data row11 col3" >0.0280</td>
#       <td id="T_c3e38_row11_col4" class="data row11 col4" >0.0035</td>
#       <td id="T_c3e38_row11_col5" class="data row11 col5" >0.0026</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['total_filters', 'kernel_size',
#                                               'input_size', 'filters_per_layer',
#                                               'number_of_layers'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=['tpu_mode', 'usb_type',
#                                               'block_type'],
#                                      transformer=SimpleImputer(strategy='most_frequent'))),
#                  ('...
#                                                                           'data_type': dtype('O'),
#                                                                           'mapping': max    0
#  std    1
#  NaN   -1
#  dtype: int64},
#                                                                          {'col': 'usb_type',
#                                                                           'data_type': dtype('O'),
#                                                                           'mapping': usb2    0
#  usb3    1
#  NaN    -1
#  dtype: int64}]))),
#                  ('onehot_encoding',
#                   TransformerWrapper(include=['block_type'],
#                                      transformer=OneHotEncoder(cols=['block_type'],
#                                                                handle_missing='return_nan',
#                                                                use_cat_names=True))),
#                  ('actual_estimator',
#                   ExtraTreesRegressor(n_jobs=-1, random_state=42))]),
#  '../models/power_model.pkl')

# %%
features = ['total_filters', 'kernel_size', 'input_size', 'tpu_mode', 'usb_type', 'block_type', 'filters_per_layer', 'number_of_layers', 'inference_time_per_input']
X_inference = df[features]
X_inference
# Out:
#       total_filters  kernel_size  input_size tpu_mode usb_type block_type  \
# 0             26624            1        9216      std     usb2   fullconv
# 1             40960            1        9216      std     usb2   fullconv
# 2             31744            1        9216      std     usb2   fullconv
# 3             44288            1        9216      std     usb2   fullconv
# 4             61568            1        9216      std     usb2   fullconv
# ...             ...          ...         ...      ...      ...        ...
# 2613             50            3      192000      max     usb3  separable
# 2614             50            3      256000      max     usb3  separable
# 2615             50            3      384000      max     usb3  separable
# 2616             50            3      512000      max     usb3  separable
# 2617             50            3      640000      max     usb3  separable
#
#       filters_per_layer  number_of_layers  inference_time_per_input
# 0                  1024                26                  5.453409
# 1                  1024                40                  9.393047
# 2                   128               248                  0.050065
# 3                   128               346                  0.067698
# 4                   128               481                  0.096414
# ...                 ...               ...                       ...
# 2613                 10                 5                  0.025000
# 2614                 10                 5                  0.035000
# 2615                 10                 5                  0.055000
# 2616                 10                 5                  0.070000
# 2617                 10                 5                  0.090000
#
# [2618 rows x 9 columns]

# %%
from pycaret.regression import *
inference_models = setup(data = X_inference, target = 'inference_time_per_input', session_id = "42")
# Out:
# <style type="text/css">
# #T_11d40_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_11d40">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_11d40_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_11d40_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_11d40_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_11d40_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_11d40_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_11d40_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_11d40_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_11d40_row1_col1" class="data row1 col1" >inference_time_per_input</td>
#     </tr>
#     <tr>
#       <th id="T_11d40_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_11d40_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_11d40_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_11d40_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_11d40_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_11d40_row3_col1" class="data row3 col1" >(2618, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_11d40_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_11d40_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_11d40_row4_col1" class="data row4 col1" >(2618, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_11d40_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_11d40_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_11d40_row5_col1" class="data row5 col1" >(1832, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_11d40_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_11d40_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_11d40_row6_col1" class="data row6 col1" >(786, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_11d40_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_11d40_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_11d40_row7_col1" class="data row7 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_11d40_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_11d40_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_11d40_row8_col1" class="data row8 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_11d40_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_11d40_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_11d40_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_11d40_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_11d40_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_11d40_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_11d40_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_11d40_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_11d40_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_11d40_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_11d40_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_11d40_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_11d40_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_11d40_row13_col0" class="data row13 col0" >Maximum one-hot encoding</td>
#       <td id="T_11d40_row13_col1" class="data row13 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_11d40_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_11d40_row14_col0" class="data row14 col0" >Encoding method</td>
#       <td id="T_11d40_row14_col1" class="data row14 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_11d40_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_11d40_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_11d40_row15_col1" class="data row15 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_11d40_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_11d40_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_11d40_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_11d40_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_11d40_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_11d40_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_11d40_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_11d40_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_11d40_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_11d40_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_11d40_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_11d40_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_11d40_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_11d40_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_11d40_row20_col1" class="data row20 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_11d40_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_11d40_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_11d40_row21_col1" class="data row21 col1" >509e</td>
#     </tr>
#   </tbody>
# </table>

# %%
best_inference_models = inference_models.compare_models(sort="MAE")
# Out:
# <style type="text/css">
# #T_15e37 th {
#   text-align: left;
# }
# #T_15e37_row0_col0, #T_15e37_row1_col0, #T_15e37_row1_col1, #T_15e37_row1_col2, #T_15e37_row1_col3, #T_15e37_row1_col4, #T_15e37_row1_col5, #T_15e37_row1_col6, #T_15e37_row2_col0, #T_15e37_row2_col1, #T_15e37_row2_col2, #T_15e37_row2_col3, #T_15e37_row2_col4, #T_15e37_row2_col5, #T_15e37_row2_col6, #T_15e37_row3_col0, #T_15e37_row3_col1, #T_15e37_row3_col2, #T_15e37_row3_col3, #T_15e37_row3_col4, #T_15e37_row3_col5, #T_15e37_row3_col6, #T_15e37_row4_col0, #T_15e37_row4_col1, #T_15e37_row4_col2, #T_15e37_row4_col3, #T_15e37_row4_col4, #T_15e37_row4_col5, #T_15e37_row4_col6, #T_15e37_row5_col0, #T_15e37_row5_col1, #T_15e37_row5_col2, #T_15e37_row5_col3, #T_15e37_row5_col4, #T_15e37_row5_col5, #T_15e37_row5_col6, #T_15e37_row6_col0, #T_15e37_row6_col1, #T_15e37_row6_col2, #T_15e37_row6_col3, #T_15e37_row6_col4, #T_15e37_row6_col5, #T_15e37_row6_col6, #T_15e37_row7_col0, #T_15e37_row7_col1, #T_15e37_row7_col2, #T_15e37_row7_col3, #T_15e37_row7_col4, #T_15e37_row7_col5, #T_15e37_row7_col6, #T_15e37_row8_col0, #T_15e37_row8_col1, #T_15e37_row8_col2, #T_15e37_row8_col3, #T_15e37_row8_col4, #T_15e37_row8_col5, #T_15e37_row8_col6, #T_15e37_row9_col0, #T_15e37_row9_col1, #T_15e37_row9_col2, #T_15e37_row9_col3, #T_15e37_row9_col4, #T_15e37_row9_col5, #T_15e37_row9_col6, #T_15e37_row10_col0, #T_15e37_row10_col1, #T_15e37_row10_col2, #T_15e37_row10_col3, #T_15e37_row10_col4, #T_15e37_row10_col5, #T_15e37_row10_col6, #T_15e37_row11_col0, #T_15e37_row11_col1, #T_15e37_row11_col2, #T_15e37_row11_col3, #T_15e37_row11_col4, #T_15e37_row11_col5, #T_15e37_row11_col6, #T_15e37_row12_col0, #T_15e37_row12_col1, #T_15e37_row12_col2, #T_15e37_row12_col3, #T_15e37_row12_col4, #T_15e37_row12_col5, #T_15e37_row12_col6, #T_15e37_row13_col0, #T_15e37_row13_col1, #T_15e37_row13_col2, #T_15e37_row13_col3, #T_15e37_row13_col4, #T_15e37_row13_col5, #T_15e37_row13_col6, #T_15e37_row14_col0, #T_15e37_row14_col1, #T_15e37_row14_col2, #T_15e37_row14_col3, #T_15e37_row14_col4, #T_15e37_row14_col5, #T_15e37_row14_col6, #T_15e37_row15_col0, #T_15e37_row15_col1, #T_15e37_row15_col2, #T_15e37_row15_col3, #T_15e37_row15_col4, #T_15e37_row15_col5, #T_15e37_row15_col6, #T_15e37_row16_col0, #T_15e37_row16_col1, #T_15e37_row16_col2, #T_15e37_row16_col3, #T_15e37_row16_col4, #T_15e37_row16_col5, #T_15e37_row16_col6, #T_15e37_row17_col0, #T_15e37_row17_col1, #T_15e37_row17_col2, #T_15e37_row17_col3, #T_15e37_row17_col4, #T_15e37_row17_col5, #T_15e37_row17_col6, #T_15e37_row18_col0, #T_15e37_row18_col1, #T_15e37_row18_col2, #T_15e37_row18_col3, #T_15e37_row18_col4, #T_15e37_row18_col5, #T_15e37_row18_col6 {
#   text-align: left;
# }
# #T_15e37_row0_col1, #T_15e37_row0_col2, #T_15e37_row0_col3, #T_15e37_row0_col4, #T_15e37_row0_col5, #T_15e37_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_15e37_row0_col7, #T_15e37_row1_col7, #T_15e37_row2_col7, #T_15e37_row3_col7, #T_15e37_row4_col7, #T_15e37_row5_col7, #T_15e37_row6_col7, #T_15e37_row7_col7, #T_15e37_row8_col7, #T_15e37_row9_col7, #T_15e37_row10_col7, #T_15e37_row11_col7, #T_15e37_row12_col7, #T_15e37_row14_col7, #T_15e37_row15_col7, #T_15e37_row16_col7, #T_15e37_row17_col7, #T_15e37_row18_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_15e37_row13_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_15e37">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_15e37_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_15e37_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_15e37_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_15e37_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_15e37_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_15e37_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_15e37_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_15e37_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_15e37_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_15e37_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_15e37_row0_col1" class="data row0 col1" >0.2522</td>
#       <td id="T_15e37_row0_col2" class="data row0 col2" >28.4401</td>
#       <td id="T_15e37_row0_col3" class="data row0 col3" >2.5995</td>
#       <td id="T_15e37_row0_col4" class="data row0 col4" >0.9094</td>
#       <td id="T_15e37_row0_col5" class="data row0 col5" >0.0926</td>
#       <td id="T_15e37_row0_col6" class="data row0 col6" >0.1286</td>
#       <td id="T_15e37_row0_col7" class="data row0 col7" >0.2030</td>
#     </tr>
#     <tr>
#       <th id="T_15e37_level0_row1" class="row_heading level0 row1" >catboost</th>
#       <td id="T_15e37_row1_col0" class="data row1 col0" >CatBoost Regressor</td>
#       <td id="T_15e37_row1_col1" class="data row1 col1" >0.3527</td>
#       <td id="T_15e37_row1_col2" class="data row1 col2" >32.9476</td>
#       <td id="T_15e37_row1_col3" class="data row1 col3" >2.9225</td>
#       <td id="T_15e37_row1_col4" class="data row1 col4" >0.8939</td>
#       <td id="T_15e37_row1_col5" class="data row1 col5" >0.1075</td>
#       <td id="T_15e37_row1_col6" class="data row1 col6" >2.1550</td>
#       <td id="T_15e37_row1_col7" class="data row1 col7" >0.7960</td>
#     </tr>
#     <tr>
#       <th id="T_15e37_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_15e37_row2_col0" class="data row2 col0" >Random Forest Regressor</td>
#       <td id="T_15e37_row2_col1" class="data row2 col1" >0.5707</td>
#       <td id="T_15e37_row2_col2" class="data row2 col2" >36.7998</td>
#       <td id="T_15e37_row2_col3" class="data row2 col3" >4.2346</td>
#       <td id="T_15e37_row2_col4" class="data row2 col4" >0.8146</td>
#       <td id="T_15e37_row2_col5" class="data row2 col5" >0.1550</td>
#       <td id="T_15e37_row2_col6" class="data row2 col6" >0.3185</td>
#       <td id="T_15e37_row2_col7" class="data row2 col7" >0.1690</td>
#     </tr>
#     <tr>
#       <th id="T_15e37_level0_row3" class="row_heading level0 row3" >dt</th>
#       <td id="T_15e37_row3_col0" class="data row3 col0" >Decision Tree Regressor</td>
#       <td id="T_15e37_row3_col1" class="data row3 col1" >0.6021</td>
#       <td id="T_15e37_row3_col2" class="data row3 col2" >65.0110</td>
#       <td id="T_15e37_row3_col3" class="data row3 col3" >5.3682</td>
#       <td id="T_15e37_row3_col4" class="data row3 col4" >0.6022</td>
#       <td id="T_15e37_row3_col5" class="data row3 col5" >0.1733</td>
#       <td id="T_15e37_row3_col6" class="data row3 col6" >0.2597</td>
#       <td id="T_15e37_row3_col7" class="data row3 col7" >0.0280</td>
#     </tr>
#     <tr>
#       <th id="T_15e37_level0_row4" class="row_heading level0 row4" >gbr</th>
#       <td id="T_15e37_row4_col0" class="data row4 col0" >Gradient Boosting Regressor</td>
#       <td id="T_15e37_row4_col1" class="data row4 col1" >1.0109</td>
#       <td id="T_15e37_row4_col2" class="data row4 col2" >64.2395</td>
#       <td id="T_15e37_row4_col3" class="data row4 col3" >6.5127</td>
#       <td id="T_15e37_row4_col4" class="data row4 col4" >0.3207</td>
#       <td id="T_15e37_row4_col5" class="data row4 col5" >0.2690</td>
#       <td id="T_15e37_row4_col6" class="data row4 col6" >8.4095</td>
#       <td id="T_15e37_row4_col7" class="data row4 col7" >0.0950</td>
#     </tr>
#     <tr>
#       <th id="T_15e37_level0_row5" class="row_heading level0 row5" >lightgbm</th>
#       <td id="T_15e37_row5_col0" class="data row5 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_15e37_row5_col1" class="data row5 col1" >1.3200</td>
#       <td id="T_15e37_row5_col2" class="data row5 col2" >52.4851</td>
#       <td id="T_15e37_row5_col3" class="data row5 col3" >6.1394</td>
#       <td id="T_15e37_row5_col4" class="data row5 col4" >0.6064</td>
#       <td id="T_15e37_row5_col5" class="data row5 col5" >0.4030</td>
#       <t

# %%
plot_model(best_inference_models, plot = 'error')

# %%
plot_model(best_inference_models, plot = 'feature')

# %%
tuned_inference_model = tune_model(best_inference_models, n_iter = 50)
evaluate_model(tuned_inference_model)
final_inference_model = finalize_model(tuned_inference_model)
save_model(final_inference_model, '../models/inference_model')
# Out:
# <style type="text/css">
# #T_27656_row10_col0, #T_27656_row10_col1, #T_27656_row10_col2, #T_27656_row10_col3, #T_27656_row10_col4, #T_27656_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_27656">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_27656_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_27656_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_27656_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_27656_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_27656_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_27656_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_27656_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_27656_row0_col0" class="data row0 col0" >1.8527</td>
#       <td id="T_27656_row0_col1" class="data row0 col1" >82.3573</td>
#       <td id="T_27656_row0_col2" class="data row0 col2" >9.0751</td>
#       <td id="T_27656_row0_col3" class="data row0 col3" >0.6378</td>
#       <td id="T_27656_row0_col4" class="data row0 col4" >0.3234</td>
#       <td id="T_27656_row0_col5" class="data row0 col5" >14.8284</td>
#     </tr>
#     <tr>
#       <th id="T_27656_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_27656_row1_col0" class="data row1 col0" >0.7682</td>
#       <td id="T_27656_row1_col1" class="data row1 col1" >12.5663</td>
#       <td id="T_27656_row1_col2" class="data row1 col2" >3.5449</td>
#       <td id="T_27656_row1_col3" class="data row1 col3" >0.8720</td>
#       <td id="T_27656_row1_col4" class="data row1 col4" >0.3517</td>
#       <td id="T_27656_row1_col5" class="data row1 col5" >21.2798</td>
#     </tr>
#     <tr>
#       <th id="T_27656_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_27656_row2_col0" class="data row2 col0" >0.4251</td>
#       <td id="T_27656_row2_col1" class="data row2 col1" >2.2799</td>
#       <td id="T_27656_row2_col2" class="data row2 col2" >1.5099</td>
#       <td id="T_27656_row2_col3" class="data row2 col3" >0.9486</td>
#       <td id="T_27656_row2_col4" class="data row2 col4" >0.2678</td>
#       <td id="T_27656_row2_col5" class="data row2 col5" >16.8631</td>
#     </tr>
#     <tr>
#       <th id="T_27656_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_27656_row3_col0" class="data row3 col0" >0.7713</td>
#       <td id="T_27656_row3_col1" class="data row3 col1" >7.8744</td>
#       <td id="T_27656_row3_col2" class="data row3 col2" >2.8061</td>
#       <td id="T_27656_row3_col3" class="data row3 col3" >0.7379</td>
#       <td id="T_27656_row3_col4" class="data row3 col4" >0.2827</td>
#       <td id="T_27656_row3_col5" class="data row3 col5" >19.1371</td>
#     </tr>
#     <tr>
#       <th id="T_27656_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_27656_row4_col0" class="data row4 col0" >0.6194</td>
#       <td id="T_27656_row4_col1" class="data row4 col1" >5.6401</td>
#       <td id="T_27656_row4_col2" class="data row4 col2" >2.3749</td>
#       <td id="T_27656_row4_col3" class="data row4 col3" >0.7586</td>
#       <td id="T_27656_row4_col4" class="data row4 col4" >0.2978</td>
#       <td id="T_27656_row4_col5" class="data row4 col5" >15.2724</td>
#     </tr>
#     <tr>
#       <th id="T_27656_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_27656_row5_col0" class="data row5 col0" >1.7494</td>
#       <td id="T_27656_row5_col1" class="data row5 col1" >129.8041</td>
#       <td id="T_27656_row5_col2" class="data row5 col2" >11.3932</td>
#       <td id="T_27656_row5_col3" class="data row5 col3" >0.5288</td>
#       <td id="T_27656_row5_col4" class="data row5 col4" >0.3622</td>
#       <td id="T_27656_row5_col5" class="data row5 col5" >13.4716</td>
#     </tr>
#     <tr>
#       <th id="T_27656_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_27656_row6_col0" class="data row6 col0" >1.5451</td>
#       <td id="T_27656_row6_col1" class="data row6 col1" >63.2596</td>
#       <td id="T_27656_row6_col2" class="data row6 col2" >7.9536</td>
#       <td id="T_27656_row6_col3" class="data row6 col3" >0.7262</td>
#       <td id="T_27656_row6_col4" class="data row6 col4" >0.3015</td>
#       <td id="T_27656_row6_col5" class="data row6 col5" >14.0770</td>
#     </tr>
#     <tr>
#       <th id="T_27656_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_27656_row7_col0" class="data row7 col0" >0.7830</td>
#       <td id="T_27656_row7_col1" class="data row7 col1" >6.5763</td>
#       <td id="T_27656_row7_col2" class="data row7 col2" >2.5644</td>
#       <td id="T_27656_row7_col3" class="data row7 col3" >0.7413</td>
#       <td id="T_27656_row7_col4" class="data row7 col4" >0.3746</td>
#       <td id="T_27656_row7_col5" class="data row7 col5" >19.1879</td>
#     </tr>
#     <tr>
#       <th id="T_27656_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_27656_row8_col0" class="data row8 col0" >1.6351</td>
#       <td id="T_27656_row8_col1" class="data row8 col1" >232.3478</td>
#       <td id="T_27656_row8_col2" class="data row8 col2" >15.2430</td>
#       <td id="T_27656_row8_col3" class="data row8 col3" >0.3727</td>
#       <td id="T_27656_row8_col4" class="data row8 col4" >0.2794</td>
#       <td id="T_27656_row8_col5" class="data row8 col5" >12.1435</td>
#     </tr>
#     <tr>
#       <th id="T_27656_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_27656_row9_col0" class="data row9 col0" >0.5385</td>
#       <td id="T_27656_row9_col1" class="data row9 col1" >8.3391</td>
#       <td id="T_27656_row9_col2" class="data row9 col2" >2.8878</td>
#       <td id="T_27656_row9_col3" class="data row9 col3" >0.8560</td>
#       <td id="T_27656_row9_col4" class="data row9 col4" >0.3038</td>
#       <td id="T_27656_row9_col5" class="data row9 col5" >21.1334</td>
#     </tr>
#     <tr>
#       <th id="T_27656_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_27656_row10_col0" class="data row10 col0" >1.0688</td>
#       <td id="T_27656_row10_col1" class="data row10 col1" >55.1045</td>
#       <td id="T_27656_row10_col2" class="data row10 col2" >5.9353</td>
#       <td id="T_27656_row10_col3" class="data row10 col3" >0.7180</td>
#       <td id="T_27656_row10_col4" class="data row10 col4" >0.3145</td>
#       <td id="T_27656_row10_col5" class="data row10 col5" >16.7394</td>
#     </tr>
#     <tr>
#       <th id="T_27656_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_27656_row11_col0" class="data row11 col0" >0.5276</td>
#       <td id="T_27656_row11_col1" class="data row11 col1" >71.8497</td>
#       <td id="T_27656_row11_col2" class="data row11 col2" >4.4583</td>
#       <td id="T_27656_row11_col3" class="data row11 col3" >0.1613</td>
#       <td id="T_27656_row11_col4" class="data row11 col4" >0.0351</td>
#       <td id="T_27656_row11_col5" class="data row11 col5" >3.1044</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['total_filters', 'kernel_size',
#                                               'input_size', 'filters_per_layer',
#                                               'number_of_layers'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=['tpu_mode', 'usb_type',
#                                               'block_type'],
#                                      transformer=SimpleImputer(strategy='most_frequent'))),
#                  ('...
#                                                                           'data_type': dtype('O'),
#                                                                           'mapping': max    0
#  std    1
#  NaN   -1
#  dtype: int64},
#                                                                          {'col': 'usb_type',
#                                                                           'data_type': dtype('O'),
#                                                                           'mapping': usb2    0
#  usb3    1
#  NaN    -1
#  dtype: int64}]))),
#                  ('onehot_encoding',
#                   TransformerWrapper(include=['block_type'],
#                                      transformer=OneHotEncoder(cols=['block_type'],
#                                                                handle_missing='return_nan',
#                                                                use_cat_names=True))),
#                  ('actual_estimator',
#                   ExtraTreesRegressor(n_jobs=-1, random_state=42))]),
#  '../models/inference_model.pkl')

# %%
# Create a DataFrame with the extracted data
data = {
    'Features': ['TPU Mode', 'Kernel Size', 'Fullconv (Block Type)', 'Separable (Block Type)', 'Input Size', '# Layers', 'Filters', 'GLU (Block Type)', 'USB Type', 'Filters per Layer'],
    'Variable Importance': [0.03, 0.04, 0.05, 0.003, 0.04, 0.07, 0.12, 0.01, 0.51, 0.14]
}
df0 = pd.DataFrame(data)
df0["Model"] = "Power"

data = {
    'Features': ['TPU Mode', 'Kernel Size', 'Fullconv (Block Type)', 'Separable (Block Type)', 
                 'Input Size', '# Layers', 'Filters', 'GLU (Block Type)', 
                 'USB Type', 'Filters per Layer'],
    'Variable Importance': [0.003, 0.003, 0.003, 0.003, 0.003, 0.09, 0.10, 0.18, 0.25, 0.37]
}

df1 = pd.DataFrame(data)
df1["Model"] = "Inference Time"

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

palette_ = sns.cubehelix_palette(start=.5, rot=-.5)

plt.figure(figsize=(7, 4))
bar_plot = sns.barplot(data=pd.concat([df0,df1]), x="Variable Importance", y="Features", hue="Model", palette=[palette_[1], palette_[-1]])

bar_plot.set_title('Feature Importance Plot')
bar_plot.set_xlabel('Variable Importance')
bar_plot.set_ylabel('Features')
bar_plot.figure.savefig("../output/feature_importance.png")
